# %%
exec(open('scrape_parcels.py').read())

# %%
df['valueperacre'] = df.valueperacre.replace([np.inf, 0], np.NaN)

# %%
df.plot(column='valueperacre', figsize=(25,25), legend=True, missing_kwds={'color': 'lightgrey'})
# Out:
# <AxesSubplot:>

# %%
df.valueperacre.value_counts()
# Out:
# 4.667151e+05    65
# 5.227209e+05    45
# 6.534012e+05    43
# 6.969612e+05    42
# 3.630007e+05    40
#                 ..
# 4.159987e+05     1
# 5.921448e+05     1
# 1.024466e+07     1
# 4.176862e+05     1
# 5.388473e+05     1
# Name: valueperacre, Length: 58965, dtype: int64

# %%
df.valueperacre.replace([np.inf, 0], np.NaN).value_counts()
# Out:
# 4.667151e+05    65
# 5.227209e+05    45
# 6.534012e+05    43
# 6.969612e+05    42
# 3.630007e+05    40
#                 ..
# 4.159987e+05     1
# 5.921448e+05     1
# 1.024466e+07     1
# 4.176862e+05     1
# 5.388473e+05     1
# Name: valueperacre, Length: 58965, dtype: int64

# %%
import numpy as np
